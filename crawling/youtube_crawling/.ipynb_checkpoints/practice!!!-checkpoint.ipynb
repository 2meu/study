# %%
from bs4 import BeautifulSoup

html = '''
<html><body>
<div id='meigen'>
    <h1>wiki book</h1>
    <ul class='items'>
        <li>unity game effect access level</li>
        <li>iphone app devlopement book by starting swift</li>
        <li>modern website design base</li>
    </ul>
</div>
</body></html>
'''

soup = BeautifulSoup(html, 'html.parser')

text = soup.select_one("li")

for i in text:
    print(i.string)
# Out:
# unity game effect access level

# %%
from bs4 import BeautifulSoup

html = '''
<html><body>
    <ul>
        <li><a href = "http://www.naver.com">naver</a></li>
        <li><a href = "http://www.daum.net">daum</a></li>
    <ul>
</body></html>
'''

soup = BeautifulSoup(html, 'html.parser')

links = soup.find_all('a')

print(links)

print(links[0].attrs['href'])

for a in links:
    href = a.attrs['href']
    text = a.string
    print(text, " > ", href)
# Out:
# [<a href="http://www.naver.com">naver</a>, <a href="http://www.daum.net">daum</a>]
# http://www.naver.com
# naver  >  http://www.naver.com
# daum  >  http://www.daum.net

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import requests

url = 'https://finance.naver.com/marketindex/'
res = requests.get(url).text
#res = req.urlopen(url)

soup = BeautifulSoup(res, 'html.parser')

price = soup.select_one("div.head_info > span.value")

print(price.string)
# Out:
# 1,128.50

# %%
#mw-content-text > div > ul:nth-child(6) > li > b > a

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import re

url = 'https://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC'
res = req.urlopen(url)
soup = BeautifulSoup(res, 'html.parser')

a_list = soup.select_one('#mw-content-text > div > ul > li > a')

for a in a_list:
    titles = a.attrs['title']
    print(titles)
    
#mw-content-text > div > ul:nth-child(7) > li:nth-child(1) > a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-57d74f337b88> in <module>()
#      10
#      11 for a in a_list:
# ---> 12     titles = a.attrs['title']
#      13     print(titles)
#      14
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     735             raise AttributeError(
#     736                 "'%s' object has no attribute '%s'" % (
# --> 737                     self.__class__.__name__, attr))
#     738
#     739     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'attrs'

# %%
html = """
<ul>
    <li><a href="hoge.html">hoge</li>
    <li><a href="https://example.com/fuga">fuga*</li>
    <li><a href="https://example.com/foo">foo*</li>
</ul>
"""

from bs4 import BeautifulSoup
import re

soup = BeautifulSoup(html, 'html.parser')

lists = soup.find_all(href=re.compile(r'^https://'))

for li in lists: 
    print(li.attrs['href'])
# Out:
# https://example.com/fuga
# https://example.com/foo

# %%
# game of throne

import requests
from bs4 import BeautifulSoup

url = 'https://www.youtube.com/watch?v=rlR4PJn8b8I'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())

title = soup.select_one("#Info-contents > h1 > yt-formatted-string")
print(title)
# Out:
# <!DOCTYPE html>
# <html data-cast-api-enabled="true" lang="ko">
#  <head>
#   <style name="www-roboto">
#    @font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}
#   </style>
#   <script name="www-roboto">
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "http://2dub.me/"
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())

title = soup.find_all("h1", {'class' : "title style-scope ytd-video-primary-info-renderer"})
print(title.strip())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/style.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/onepage.css" rel="stylesheet" type="text/css"/>
#   <style>
#    .policy-link{
#             color:#9B9B9B;
#         }
#   </style>
#   <title>
#    2MEU - 2DUB(투덥) [당신이 주인공이 되어보세요!]
#   </title>
#  </head>
#  <body class="stretched side-push-panel lang_">
#   <div class="body-overlay">
#   </div>
#   <div class="dark" id="side-panel">
#    <div class="side-panel-trigger" id="side-panel-trigger-close">
#     <a href="#a">
#      <i class="icon-line-cross">
#      </i>
#     </a>
#    </div>
#   </div>
#   <div class="clearfix" id="wrapper">
# ...

# %%
import requests
from bs4 import BeautifulSoup
import lxml

eminem_video_info = {
    'title':'',
    'video_link':'',
    'img_link':'',
    'play_time':'',
    'hits':'',
    'update_time':''
}

def get_eminem_video_link(target_url):
    response = requests.get(target_url)
    soup = (response.text, 'lxml')
    return eminem_video_info

target_url = 'https://www.youtube.com/user/EminemVEVO/videos'
get_eminem_video_link(target_url)

# %%
import lxml

eminem_video_info = {
    'title':'',
    'video_link':'',
    'img_link':'',
    'play_time':'',
    'hits':'',
    'update_time':''
}

def get_eminem_video_link(target_url):
    response = requests.get(target_url)
    soup = BeautifulSoup(response.text, "lxml")
    lis = soup.find_all('a', attrs = {'class':'yt-simple-endpoint inline-block style-scope ytd-thumbnail'})
    

target_url = 'https://www.youtube.com/user/EminemVEVO/videos'
get_eminem_video_link(target_url)
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup
import lxml

target_url = 'https://www.youtube.com/user/EminemVEVO/videos'
response = requests.get(target_url)
soup = BeautifulSoup(response.text, "lxml")
lis = soup.find('a', {'class':'yt-simple-endpoint'})
print(lis)
# Out:
# None

# %%
from bs4 import BeautifulSoup
import requests
import lxml

def get_true_video_link(target_url):
    response = requests.get(target_url)
    soup = BeautifulSoup(response.text, "lxml")
    lis = soup.find_all('li', {'class' : 'channels-content-item yt-shelf-grid-item'})
    for li in lis:
        title = li.find('a', {'title' : True})['title']
        video_link = 'https://www.youtube.com' + li.find('a', {'href' : True})['href']
        img_link = li.find('img', {'src' : True})['src']
        play_time = li.find('span', {'class' : 'video-time'}).text
        hits = li.find_all('li')[2].text
        updated_time = li.find_all('li')[3].text
        true_video_info = title, video_link, img_link, play_time, hits, updated_time
        print(true_video_info)
    return true_video_info


target_url = 'https://www.youtube.com/user/yootruebeutyroom/videos'
get_true_video_link(target_url)
# Out:
# ('눈썹 왕 상세하게, 자연스러운 봄 메이크업🌸/눈썹 실수 3가지 혹시.. 나?!', 'https://www.youtube.com/watch?v=JKVcRlNz2UA', 'https://i.ytimg.com/vi/JKVcRlNz2UA/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLAqOn5ayA9fHhCMFk0y6HqLnDUzTQ', '22:46', '조회수 62,176회', '2일 전')
# ('꾸셀브러쉬? 꾸셀저렴이? 메포 브러쉬와 비교?ㅣ세세하게 분석 리뷰!', 'https://www.youtube.com/watch?v=vGCCtYlXg4A', 'https://i.ytimg.com/vi/vGCCtYlXg4A/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLAeZ5pBxWTg-Cihk9PrrqD2IC-HEw', '8:42', '조회수 64,396회', '4일 전')
# ('이사 전 마지막 룸메이트/수다 가득!ㅣ디올 포에버피팅 파운데이션', 'https://www.youtube.com/watch?v=OtfaeMV94OE', 'https://i.ytimg.com/vi/OtfaeMV94OE/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLCCZNaA1jWHrTSbN0hbjt64zWAp9w', '32:04', '조회수 94,858회', '1주 전')
# ...

# %%
from bs4 import BeautifulSoup
import lxml
import requests

eminem_video_info = {
    'title':'',
    'video_link':'',
    'img_link':'',
    'play_time':'',
    'hits' : '',
    'updated_time':''
}

def get_eminem_video_link(target_url):
    response = requests.get(target_url)
    soup = BeautifulSoup(response.text, "lxml")
    lis = soup.find_all('li', {'class' : 'channels-content-item yt-shelf-grid-item'})
    for li in lis :
        title = li.find('a', {'title' : True})['title']
        video_link = 'https://www.youtube.com' + li.find('a', {'href' : True})['href']
        img_link = li.find('img', {'src' : True})['src']
        play_time = li.find('span', {'class' : 'video-time'}).text
        hits = li.find_all('li')[2].text
        updated_time = li.find_all('li')[3].text
        eminem_video_info = {
            'title' : title,
            'video_link' : video_link,
            'img_link' : img_link,
            'play_time' : play_time,
            'hits' : hits,
            'updated_time' : updated_time
            }
        print(eminem_video_info)
    return eminem_video_info

target_url = 'https://www.youtube.com/channel/UCc4OuY3PeWklqBzQ3ySi3xA/videos'
get_eminem_video_link(target_url)
# Out:
# {'title': '현재 트럼프가 아베한테 한 말때문에 난리난 일본상황', 'video_link': 'https://www.youtube.com/watch?v=50GzE-2ziDE', 'img_link': 'https://i.ytimg.com/vi/50GzE-2ziDE/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLC2LE-f7lFqFNJ2MXSCIABC2S3iVQ', 'play_time': '2:46', 'hits': '조회수 225,476회', 'updated_time': '15시간 전'}
# {'title': '북한에 후쿠시마산 농수산물이 유통되는 충격적인 이유', 'video_link': 'https://www.youtube.com/watch?v=smKj9gt9mVQ', 'img_link': 'https://i.ytimg.com/vi/smKj9gt9mVQ/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLCyj-FTrXVlIOizSHCy0AVQsYBy4g', 'play_time': '2:46', 'hits': '조회수 26,696회', 'updated_time': '18시간 전'}
# ...

# %%
eminem_video_info
# Out:
# {'title': '',
#  'video_link': '',
#  'img_link': '',
#  'play_time': '',
#  'hits': '',
#  'updated_time': ''}

# %%
from urllib.parse import urljoin

base = "http://example.com/html/a.html"
